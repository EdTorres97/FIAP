# %%
import json
import pandas as pd

# Função genérica para carregar JSON
def carregar_json(caminho):
    with open(caminho, 'r', encoding='utf-8') as f:
        return json.load(f)

# Função para processar arquivos no formato de prospects
def processar_prospects(json_data):
    lista = []
    for id_vaga, info in json_data.items():
        titulo = info.get("titulo", "")
        modalidade = info.get("modalidade", "")
        for prospect in info.get("prospects", []):
            prospect.update({
                "id_vaga": id_vaga,
                "titulo_vaga": titulo,
                "modalidade": modalidade
            })
            lista.append(prospect)
    return pd.DataFrame(lista)

# Função para processar arquivos no formato de vagas
def processar_vagas(json_data):
    lista = []
    for id_vaga, dados_vaga in json_data.items():
        item = {"id_vaga": id_vaga}
        for secao, valores in dados_vaga.items():
            if isinstance(valores, dict):
                for chave, valor in valores.items():
                    item[f"{secao}_{chave}"] = valor
        lista.append(item)
    return pd.DataFrame(lista)

# Função para processar arquivos no formato de applicants
def processar_applicants(json_data):
    lista = []
    for id_candidato, dados in json_data.items():
        base = {"id_candidato": id_candidato}
        for secao, valores in dados.items():
            if isinstance(valores, dict):
                for chave, valor in valores.items():
                    base[f"{secao}_{chave}"] = valor
        lista.append(base)
    return pd.DataFrame(lista)

# Caminhos dos arquivos
paths = {
    "prospects": "../data/raw/prospects.json",
    "vagas": "../data/raw/vagas.json",
    "applicants": "../data/raw/applicants.json"
}

# Criar os DataFrames finais
RAW_RH_PROSPECTS = processar_prospects(carregar_json(paths["prospects"]))
RAW_RH_VAGAS = processar_vagas(carregar_json(paths["vagas"]))
RAW_RH_APPLICANTS = processar_applicants(carregar_json(paths["applicants"]))

# %%
print(RAW_RH_PROSPECTS.info())
RAW_RH_PROSPECTS.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nome                53759 non-null  object
#  1   codigo              53759 non-null  object
#  2   situacao_candidado  53759 non-null  object
#  3   data_candidatura    53759 non-null  object
#  4   ultima_atualizacao  53759 non-null  object
#  5   comentario          53759 non-null  object
#  6   recrutador          53759 non-null  object
#  7   id_vaga             53759 non-null  object
#  8   titulo_vaga         53759 non-null  object
#  9   modalidade          53759 non-null  object
# dtypes: object(10)
# memory usage: 4.1+ MB
# None
#                        nome codigo           situacao_candidado  \
# 0               José Vieira  25632  Encaminhado ao Requisitante
# 1  Srta. Isabela Cavalcante  25529  Encaminhado ao Requisitante
# 2     Sra. Yasmin Fernandes  25364     Contratado pela Decision
# 3            Alexia Barbosa  25360  Encaminhado ao Requisitante
# 4            Arthur Almeida  26338     Contratado pela Decision
#
#   data_candidatura ultima_atualizacao  \
# 0       25-03-2021         25-03-2021
# 1       22-03-2021         23-03-2021
# 2       17-03-2021         12-04-2021
# 3       17-03-2021         17-03-2021
# 4       29-04-2021         18-05-2021
#
#                                           comentario         recrutador  \
# 0               Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira
# 1  encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira
# 2                         Data de Inicio: 12/04/2021   Juliana Cassiano
# 3                                                      Juliana Cassiano
# 4                                                         Stella Vieira
#
#   id_vaga                                        titulo_vaga modalidade
# 0    4530                                CONSULTOR CONTROL M
# 1    4530                                CONSULTOR CONTROL M
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 3    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4    4533  2021-2605708-Microfocus Application Life Cycle...

# %%
print(RAW_RH_VAGAS.info())
RAW_RH_VAGAS.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14081 entries, 0 to 14080
# Data columns (total 45 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   id_vaga                                               14081 non-null  object
#  1   informacoes_basicas_data_requicisao                   14081 non-null  object
#  2   informacoes_basicas_limite_esperado_para_contratacao  14081 non-null  object
#  3   informacoes_basicas_titulo_vaga                       14081 non-null  object
#  4   informacoes_basicas_vaga_sap                          14081 non-null  object
#  5   informacoes_basicas_cliente                           14081 non-null  object
#  6   informacoes_basicas_solicitante_cliente               14081 non-null  object
#  7   informacoes_basicas_empresa_divisao                   14081 non-null  object
#  8   informacoes_basicas_requisitante                      14081 non-null  object
#  9   informacoes_basicas_analista_responsavel              14081 non-null  object
#  10  informacoes_basicas_tipo_contratacao                  14081 non-null  object
#  11  informacoes_basicas_prazo_contratacao                 14081 non-null  object
#  12  informacoes_basicas_objetivo_vaga                     14081 non-null  object
#  13  informacoes_basicas_prioridade_vaga                   14081 non-null  object
#  14  informacoes_basicas_origem_vaga                       14081 non-null  object
#  15  informacoes_basicas_superior_imediato                 14039 non-null  object
#  16  informacoes_basicas_nome                              9625 non-null   object
#  17  informacoes_basicas_telefone                          9319 non-null   object
#  18  perfil_vaga_pais                                      14081 non-null  object
#  19  perfil_vaga_estado                                    14081 non-null  object
#  20  perfil_vaga_cidade                                    14081 non-null  object
#  21  perfil_vaga_bairro                                    14081 non-null  object
#  22  perfil_vaga_regiao                                    14081 non-null  object
#  23  perfil_vaga_local_trabalho                            14081 non-null  object
#  24  perfil_vaga_vaga_especifica_para_pcd                  14081 non-null  object
#  25  perfil_vaga_faixa_etaria                              14081 non-null  object
#  26  perfil_vaga_horario_trabalho                          14081 non-null  object
#  27  perfil_vaga_nivel profissional                        14081 non-null  object
#  28  perfil_vaga_nivel_academico                           14081 non-null  object
#  29  perfil_vaga_nivel_ingles                              14081 non-null  object
#  30  perfil_vaga_nivel_espanhol                            14081 non-null  object
#  31  perfil_vaga_outro_idioma                              14081 non-null  object
#  32  perfil_vaga_areas_atuacao                             14081 non-null  object
#  33  perfil_vaga_principais_atividades                     14081 non-null  object
#  34  perfil_vaga_competencia_tecnicas_e_comportamentais    14081 non-null  object
#  35  perfil_vaga_demais_observacoes                        14081 non-null  object
#  36  perfil_vaga_viagens_requeridas                        14081 non-null  object
#  37  perfil_vaga_equipamentos_necessarios                  11396 non-null  object
#  38  beneficios_valor_venda                                14081 non-null  object
#  39  beneficios_valor_compra_1                             14081 non-null  object
#  40  beneficios_valor_compra_2                             14081 non-null  object
#  41  informacoes_basicas_data_inicial                      4456 non-null   object
#  42  informacoes_basicas_data_final                        4456 non-null   object
#  43  perfil_vaga_habilidades_comportamentais_necessarias   2685 non-null   object
#  44  informacoes_basicas_nome_substituto                   348 non-null    object
# dtypes: object(45)
# memory usage: 4.8+ MB
# None
#   id_vaga informacoes_basicas_data_requicisao  \
# 0    5185                          04-05-2021
# 1    5184                          04-05-2021
# 2    5183                          04-05-2021
# 3    5182                          04-05-2021
# 4    5181                          04-05-2021
#
#   informacoes_basicas_limite_esperado_para_contratacao  \
# 0                                         00-00-0000
# 1                                         00-00-0000
# 2                                         00-00-0000
# 3                                         18-05-2021
# 4                                         00-00-0000
#
#                      informacoes_basicas_titulo_vaga  \
# 0                                   Operation Lead -
# 1                             Consultor PP/QM Sênior
# 2                              ANALISTA PL/JR C/ SQL
# 3                     Technical Architect - 11894809
# 4  Consultor SAP AUTHORIZATION (BCA) -Pleno / Sênior
#
#   informacoes_basicas_vaga_sap informacoes_basicas_cliente  \
# 0                          Não    Morris, Moran and Dodson
# 1                          Não    Morris, Moran and Dodson
# 2                          Não    Morris, Moran and Dodson
# 3                          Não                 Nelson-Page
# 4                          Não               Mann and Sons
#
#   informacoes_basicas_solicitante_cliente informacoes_basicas_empresa_divisao  \
# 0                   Dra. Catarina Marques                  Decision São Paulo
# 1                   Dra. Catarina Marques                  Decision São Paulo
# 2                   Dra. Catarina Marques                  Decision São Paulo
# 3                       Dr. Raul Monteiro                  Decision São Paulo
# 4                             Cauê Fogaça                  Decision São Paulo
#
#   informacoes_basicas_requisitante informacoes_basicas_analista_responsavel  \
# 0             Maria Laura Nogueira                     Srta. Bella Ferreira
# 1             Maria Laura Nogueira                           Yasmin da Rosa
# 2             Maria Laura Nogueira                          Ana Albuquerque
# 3                  Cecília Freitas                               Clara Rios
# 4             Maria Laura Nogueira                     Srta. Bella Ferreira
#
#    ...                     perfil_vaga_demais_observacoes  \
# 0  ...            100% Remoto Período – entre 5 – 6 meses
# 1  ...                   • Início: Imediato • Fim: Jan/22
# 2  ...  Localização: Remoto Perfil: Analista Pleno ou ...
# 3  ...  Budgeted Rate - indicate currency and type (ho...
# 4  ...  contratação CLT full pela Decision locação rem...
#
#   perfil_vaga_viagens_requeridas perfil_vaga_equipamentos_necessarios  \
# 0                                                            Nenhum -
# 1                                                            Nenhum -
# 2                                                            Nenhum -
# 3                            Não                    Notebook padrão -
# 4                            Sim                             Nenhum -
#
#   beneficios_valor_venda beneficios_valor_compra_1 beneficios_valor_compra_2  \
# 0                      -                        R$
# 1                      -                        R$
# 2                      -                        R$
# 3        - p/ mês (168h)                   fechado
# 4                      -                        R$
#
#   informacoes_basicas_data_inicial informacoes_basicas_data_final  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                       18-05-2021                     17-01-2022
# 4                              NaN                            NaN
#
#   perfil_vaga_habilidades_comportamentais_necessarias  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   informacoes_basicas_nome_substituto
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 45 columns]

# %%
print(RAW_RH_APPLICANTS.info())
RAW_RH_APPLICANTS.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42482 entries, 0 to 42481
# Data columns (total 56 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id_candidato                                      42482 non-null  object
#  1   infos_basicas_telefone_recado                     42482 non-null  object
#  2   infos_basicas_telefone                            42482 non-null  object
#  3   infos_basicas_objetivo_profissional               42482 non-null  object
#  4   infos_basicas_data_criacao                        42482 non-null  object
#  5   infos_basicas_inserido_por                        42482 non-null  object
#  6   infos_basicas_email                               42482 non-null  object
#  7   infos_basicas_local                               42482 non-null  object
#  8   infos_basicas_sabendo_de_nos_por                  42482 non-null  object
#  9   infos_basicas_data_atualizacao                    42482 non-null  object
#  10  infos_basicas_codigo_profissional                 42482 non-null  object
#  11  infos_basicas_nome                                42482 non-null  object
#  12  informacoes_pessoais_data_aceite                  42482 non-null  object
#  13  informacoes_pessoais_nome                         42482 non-null  object
#  14  informacoes_pessoais_cpf                          42482 non-null  object
#  15  informacoes_pessoais_fonte_indicacao              42482 non-null  object
#  16  informacoes_pessoais_email                        42482 non-null  object
#  17  informacoes_pessoais_email_secundario             42482 non-null  object
#  18  informacoes_pessoais_data_nascimento              42482 non-null  object
#  19  informacoes_pessoais_telefone_celular             42482 non-null  object
#  20  informacoes_pessoais_telefone_recado              42482 non-null  object
#  21  informacoes_pessoais_sexo                         42482 non-null  object
#  22  informacoes_pessoais_estado_civil                 42482 non-null  object
#  23  informacoes_pessoais_pcd                          42482 non-null  object
#  24  informacoes_pessoais_endereco                     42482 non-null  object
#  25  informacoes_pessoais_skype                        42482 non-null  object
#  26  informacoes_pessoais_url_linkedin                 42482 non-null  object
#  27  informacoes_pessoais_facebook                     42482 non-null  object
#  28  informacoes_profissionais_titulo_profissional     42482 non-null  object
#  29  informacoes_profissionais_area_atuacao            42482 non-null  object
#  30  informacoes_profissionais_conhecimentos_tecnicos  42482 non-null  object
#  31  informacoes_profissionais_certificacoes           42482 non-null  object
#  32  informacoes_profissionais_outras_certificacoes    42482 non-null  object
#  33  informacoes_profissionais_remuneracao             42482 non-null  object
#  34  informacoes_profissionais_nivel_profissional      42482 non-null  object
#  35  formacao_e_idiomas_nivel_academico                42482 non-null  object
#  36  formacao_e_idiomas_nivel_ingles                   42482 non-null  object
#  37  formacao_e_idiomas_nivel_espanhol                 42482 non-null  object
#  38  formacao_e_idiomas_outro_idioma                   42482 non-null  object
#  39  formacao_e_idiomas_instituicao_ensino_superior    7209 non-null   object
#  40  formacao_e_idiomas_cursos                         7209 non-null   object
#  41  formacao_e_idiomas_ano_conclusao                  7209 non-null   object
#  42  informacoes_pessoais_download_cv                  5562 non-null   object
#  43  informacoes_profissionais_qualificacoes           944 non-null    object
#  44  informacoes_profissionais_experiencias            944 non-null    object
#  45  formacao_e_idiomas_outro_curso                    809 non-null    object
#  46  cargo_atual_id_ibrati                             944 non-null    object
#  47  cargo_atual_email_corporativo                     944 non-null    object
#  48  cargo_atual_cargo_atual                           944 non-null    object
#  49  cargo_atual_projeto_atual                         944 non-null    object
#  50  cargo_atual_cliente                               944 non-null    object
#  51  cargo_atual_unidade                               944 non-null    object
#  52  cargo_atual_data_admissao                         944 non-null    object
#  53  cargo_atual_data_ultima_promocao                  944 non-null    object
#  54  cargo_atual_nome_superior_imediato                944 non-null    object
#  55  cargo_atual_email_superior_imediato               944 non-null    object
# dtypes: object(56)
# memory usage: 18.2+ MB
# None
#   id_candidato infos_basicas_telefone_recado infos_basicas_telefone  \
# 0        31000                                      (11) 97048-2708
# 1        31001                                      (11) 93723-4396
# 2        31002                                      (11) 92399-9824
# 3        31003                                      (11) 98100-1727
# 4        31004                                      (11) 92517-2678
#
#   infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 0                                            10-11-2021 07:29:49
# 1             Analista Administrativo        10-11-2021 08:56:16
# 2         Administrativo | Financeiro        10-11-2021 09:01:00
# 3                 Área administrativa        10-11-2021 09:08:13
# 4                                            10-11-2021 09:18:46
#
#   infos_basicas_inserido_por                infos_basicas_email  \
# 0               Luna Correia       carolina_aparecida@gmail.com
# 1              Laura Pacheco           eduardo_rios@hotmail.com
# 2              Laura Pacheco  pedro_henrique_carvalho@gmail.com
# 3              Laura Pacheco         thiago_barbosa@hotmail.com
# 4          Maria Clara Pires        diogo_das_neves@hotmail.com
#
#     infos_basicas_local infos_basicas_sabendo_de_nos_por  \
# 0
# 1  São Paulo, São Paulo                           Outros
# 2  São Paulo, São Paulo                          Anúncio
# 3  São Paulo, São Paulo                 Site de Empregos
# 4
#
#   infos_basicas_data_atualizacao  ... cargo_atual_id_ibrati  \
# 0            10-11-2021 07:29:49  ...                   NaN
# 1            11-11-2021 11:10:31  ...                   NaN
# 2            10-11-2021 11:42:36  ...                   NaN
# 3            10-11-2021 16:04:51  ...                   NaN
# 4            10-11-2021 09:22:03  ...                   NaN
#
#   cargo_atual_email_corporativo cargo_atual_cargo_atual  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#   cargo_atual_projeto_atual cargo_atual_cliente cargo_atual_unidade  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
#
#   cargo_atual_data_admissao cargo_atual_data_ultima_promocao  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
# 3                       NaN                              NaN
# 4                       NaN                              NaN
#
#   cargo_atual_nome_superior_imediato cargo_atual_email_superior_imediato
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
# [5 rows x 56 columns]
